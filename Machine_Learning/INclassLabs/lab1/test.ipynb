# %% [markdown]
# Part 1: Dataset loading and inspection

# %%
import pandas as pd

file_path = '/home/chris/Desktop/ML/inclass_Lab_1_-_EDA_in_python/inclass Lab 1 - EDA in python/synthetic_covid19_dataset.csv'
data = pd.read_csv(file_path)

print(data.head())

print(data.info())

# %%
print(data.describe())

# %%
print(data.isnull().sum())

# %% [markdown]
# Part 2: Profiling the Dataset with `AutoViz`, `SweetViz`, and `pandas_profiling`
# A. Using `AutoViz` for Automatic EDA**

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()

df_autoviz = AV.AutoViz(filename=file_path)

# %%
import sweetviz as sv

report = sv.analyze(data)

report.show_html('sweetviz_report.html')

# %%
from pandas_profiling import ProfileReport

profile = ProfileReport(data, title="Dataset Profiling Report", explorative=True)

profile.to_notebook_iframe()
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       3 from pydantic.v1 import BaseSettings
#       5 profile = ProfileReport(data, title="Dataset Profiling Report", explorative=True)
#
# File ~/.local/lib/python3.10/site-packages/pandas_profiling/__init__.py:8
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
#       6 from warnings import warn
# ----> 8 from pandas_profiling.compare_reports import compare
#       9 from pandas_profiling.controller import pandas_decorator
#      10 from pandas_profiling.profile_report import ProfileReport
#
# File ~/.local/lib/python3.10/site-packages/pandas_profiling/compare_reports.py:6
#       2 from typing import Any, List, Optional, Tuple, Union
#       4 import pandas as pd
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns


data['Age'].hist(bins=30)
plt.title('Distribution of Tenure')
plt.xlabel('Tenure')
plt.ylabel('Frequency')
plt.show()

sns.kdeplot(data['Ferritin'])
plt.title('KDE Plot for Monthly Charges')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(data[['Age', 'Ferritin', 'BE']])
plt.show()

# %%
sns.countplot(data['Age'])
plt.title('Churn Distribution')
plt.show()

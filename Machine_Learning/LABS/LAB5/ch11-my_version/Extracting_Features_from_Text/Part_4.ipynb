# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv(r'C:\Users\Βαγγέλης\Desktop\Σχολή\4o Έτος\7ο Εξάμηνο\Μηχανική Μάθηση για Επιστήμη Δεδομένων και Ανάλυση\Labs\Lab 5 - Exracting Features from Text\imdb_dataset.csv')
df.rename(columns={'review': 'text'}, inplace=True)

# Display the first few rows of your dataset
df.head()
# Out:
#                                                 text sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
#remove punctuation and numbers
df['text'] = df['text'].str.replace(r'[^\w\s]', '',regex=True).str.replace(r'\d+', '', regex=True)

# %%
# set up a bag of words transformer
vectorizer = TfidfVectorizer(lowercase=True,
                             stop_words='english',
                             ngram_range=(1, 1),
                             min_df=0.05)

# %%
vectorizer.fit(df['text'])
# Out:
# TfidfVectorizer(min_df=0.05, stop_words='english')

# %%
X = vectorizer.transform(df['text'])

# %%
# create tf-idf dataframe

tfidf = pd.DataFrame(X.toarray(),
                     columns = vectorizer.get_feature_names_out())

tfidf.head()
# Out:
#    absolutely    acting   action  actor    actors  actually  american  \
# 0         0.0  0.000000  0.00000    0.0  0.000000       0.0       0.0
# 1         0.0  0.000000  0.00000    0.0  0.136865       0.0       0.0
# 2         0.0  0.000000  0.00000    0.0  0.000000       0.0       0.0
# 3         0.0  0.000000  0.00000    0.0  0.000000       0.0       0.0
# 4         0.0  0.100672  0.13784    0.0  0.000000       0.0       0.0
#
#    audience      away  awful  ...     world  worst     worth   written  wrong  \
# 0       0.0  0.158451    0.0  ...  0.000000    0.0  0.000000  0.000000    0.0
# 1       0.0  0.000000    0.0  ...  0.000000    0.0  0.156735  0.182557    0.0
# 2       0.0  0.000000    0.0  ...  0.000000    0.0  0.000000  0.000000    0.0
# 3       0.0  0.000000    0.0  ...  0.000000    0.0  0.000000  0.000000    0.0
# 4       0.0  0.000000    0.0  ...  0.125747    0.0  0.000000  0.000000    0.0
#
#    year    years  yes     young     youre
# 0   0.0  0.00000  0.0  0.000000  0.000000
# 1   0.0  0.00000  0.0  0.000000  0.000000
# 2   0.0  0.19114  0.0  0.204408  0.000000
# 3   0.0  0.00000  0.0  0.000000  0.244536
# 4   0.0  0.00000  0.0  0.000000  0.000000
#
# [5 rows x 244 columns]

# %%
tfidf.shape
# Out:
# (999, 244)

# %%
vectorizer = TfidfVectorizer(lowercase=True,
                                stop_words = 'english',
                                ngram_range=(1,2),
                                min_df=0.1)

# %%
vectorizer.fit(df['text'])
# Out:
# TfidfVectorizer(min_df=0.1, ngram_range=(1, 2), stop_words='english')

# %%
X = vectorizer.transform(df['text'])

# %%
tfidf = pd.DataFrame(X.toarray(),
                     columns = vectorizer.get_feature_names_out())

tfidf.head()
# Out:
#      acting    actors  actually  bad      best  better       big        br  \
# 0  0.000000  0.000000       0.0  0.0  0.000000     0.0  0.000000  0.372095
# 1  0.000000  0.186653       0.0  0.0  0.000000     0.0  0.000000  0.584263
# 2  0.000000  0.000000       0.0  0.0  0.000000     0.0  0.000000  0.285493
# 3  0.000000  0.000000       0.0  0.0  0.000000     0.0  0.000000  0.445010
# 4  0.139473  0.000000       0.0  0.0  0.146742     0.0  0.176236  0.415089
#
#       br br     cast  ...      time  times  want     watch  watching  \
# 0  0.000000  0.00000  ...  0.000000    0.0   0.0  0.000000  0.453456
# 1  0.542275  0.00000  ...  0.000000    0.0   0.0  0.000000  0.178004
# 2  0.000000  0.00000  ...  0.203416    0.0   0.0  0.000000  0.260938
# 3  0.000000  0.00000  ...  0.000000    0.0   0.0  0.000000  0.000000
# 4  0.154103  0.17084  ...  0.236604    0.0   0.0  0.134239  0.000000
#
#         way      work     world    years     young
# 0  0.000000  0.000000  0.000000  0.00000  0.000000
# 1  0.000000  0.000000  0.000000  0.00000  0.000000
# 2  0.220762  0.000000  0.000000  0.28172  0.301275
# 3  0.000000  0.000000  0.000000  0.00000  0.000000
# 4  0.128390  0.166793  0.174211  0.00000  0.000000
#
# [5 rows x 73 columns]

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['acting', 'actors', 'actually', 'bad', 'best', 'better', 'big',
#        'br', 'br br', 'cast', 'character', 'characters', 'come', 'did',
#        'didnt', 'director', 'does', 'doesnt', 'dont', 'end', 'film',
#        'films', 'funny', 'gets', 'going', 'good', 'got', 'great', 'im',
#        'isnt', 'just', 'know', 'life', 'like', 'little', 'long', 'look',
#        'lot', 'love', 'make', 'makes', 'man', 'movie', 'movies', 'new',
#        'old', 'people', 'plot', 'pretty', 'quite', 'real', 'really',
#        'saw', 'say', 'scene', 'scenes', 'seen', 'story', 'thats', 'thing',
#        'things', 'think', 'thought', 'time', 'times', 'want', 'watch',
#        'watching', 'way', 'work', 'world', 'years', 'young'], dtype=object)
